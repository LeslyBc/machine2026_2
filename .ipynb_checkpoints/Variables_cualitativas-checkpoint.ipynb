# %% [markdown]
# ![jupyter](img/itq-logo.png )
#
# ## Machine Learning - Variables Cualitativas
#
# ![jupyter](img/python-logo.png )
#
# *Lesly Noemi Becerra Campaña*

# %%
# Creación aleatoria de datos
import numpy as np
import random
random.seed(42)

# %%
nivel_estudios = []
nivel_estudios.extend(['Secundaria']*110)
nivel_estudios.extend(['Bachillerato']*172)
nivel_estudios.extend(['Grado']*145)
nivel_estudios.extend(['Master']*52)
nivel_estudios.extend(['Doctorado']*21)

nivel_estudios = np.random.permutation(nivel_estudios)

# %%
print(nivel_estudios)
# Out:
# ['Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Grado' 'Master'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Grado' 'Bachillerato' 'Master' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Master' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Grado' 'Doctorado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Grado' 'Master' 'Secundaria' 'Master' 'Grado' 'Secundaria' 'Doctorado'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Master'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Master' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Bachillerato' 'Grado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria' 'Master'
#  'Secundaria' 'Master' 'Grado' 'Secundaria' 'Doctorado' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Grado' 'Grado' 'Grado' 'Doctorado' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Master' 'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Doctorado'
#  'Doctorado' 'Bachillerato' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Doctorado' 'Bachillerato' 'Grado' 'Secundaria' 'Grado'
#  'Secundaria' 'Grado' 'Secundaria' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Master' 'Master' 'Grado'
#  'Secundaria' 'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Grado' 'Grado' 'Grado' 'Grado' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Grado' 'Bachillerato' 'Master' 'Bachillerato'
#  'Bachillerato' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Bachillerato' 'Master' 'Bachillerato'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Secundaria' 'Secundaria' 'Secundaria' 'Grado' 'Secundaria' 'Master'
#  'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Grado' 'Secundaria'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Secundaria' 'Master' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Secundaria'
#  'Master' 'Bachillerato' 'Secundaria' 'Doctorado' 'Bachillerato' 'Grado'
#  'Grado' 'Secundaria' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Doctorado' 'Secundaria' 'Grado' 'Grado'
#  'Bachillerato' 'Secundaria' 'Master' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Master' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado'
#  'Grado' 'Doctorado' 'Grado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Master' 'Secundaria' 'Grado' 'Grado' 'Doctorado' 'Grado' 'Bachillerato'
#  'Grado' 'Master' 'Bachillerato' 'Secundaria' 'Secundaria' 'Master'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Bachillerato' 'Master' 'Grado' 'Bachillerato' 'Master' 'Master' 'Master'
#  'Master' 'Master' 'Doctorado' 'Bachillerato' 'Grado' 'Grado' 'Secundaria'
#  'Bachillerato' 'Doctorado' 'Grado' 'Bachillerato' 'Doctorado' 'Grado'
#  'Secundaria' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Grado' 'Secundaria' 'Bachillerato' 'Secundaria' 'Master' 'Secundaria'
#  'Grado' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria' 'Grado' 'Master'
#  'Bachillerato' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Master'
#  'Master' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Secundaria' 'Grado'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Grado' 'Master' 'Master' 'Grado' 'Bachillerato'
#  'Grado' 'Secundaria' 'Secundaria' 'Doctorado' 'Secundaria' 'Bachillerato'
#  'Grado' 'Doctorado' 'Grado' 'Grado' 'Grado' 'Secundaria' 'Bachillerato'
#  'Secundaria' 'Grado' 'Secundaria' 'Grado' 'Secundaria' 'Secundaria'
#  'Grado' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Grado' 'Bachillerato' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Secundaria' 'Secundaria'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Secundaria'
#  'Bachillerato' 'Secundaria' 'Master' 'Grado' 'Grado' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Grado'
#  'Bachillerato' 'Doctorado' 'Grado' 'Master' 'Bachillerato' 'Secundaria'
#  'Master' 'Master' 'Bachillerato' 'Bachillerato' 'Doctorado'
#  'Bachillerato' 'Grado' 'Master' 'Bachillerato' 'Master' 'Bachillerato'
#  'Grado' 'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Secundaria' 'Secundaria'
#  'Grado' 'Bachillerato' 'Secundaria' 'Bachillerato' 'Grado' 'Grado'
#  'Secundaria' 'Secundaria' 'Grado' 'Bachillerato' 'Grado' 'Bachillerato'
#  'Master' 'Bachillerato' 'Grado' 'Bachillerato' 'Secundaria' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Bachillerato'
#  'Bachillerato' 'Master' 'Bachillerato' 'Bachillerato' 'Grado'
#  'Bachillerato' 'Bachillerato' 'Grado' 'Grado' 'Master' 'Master'
#  'Secundaria' 'Grado' 'Grado' 'Secundaria' 'Doctorado' 'Secundaria'
#  'Bachillerato' 'Bachillerato' 'Bachillerato' 'Master' 'Grado' 'Grado'
#  'Bachillerato']

# %%
# DIAGRAMA DE BARRAS
import matplotlib.pyplot as plt
import numpy as np
estudios, frecuencia = np.unique(nivel_estudios, return_counts=True)
print(estudios, frecuencia)
# Out:
# ['Bachillerato' 'Doctorado' 'Grado' 'Master' 'Secundaria'] [172  21 145  52 110]

# %%
plt.ylabel('Frecuencia absoluta')
plt.xlabel('Nivel de estudios')
plt.title('Diagrama de barras')
plt.bar(estudios, frecuencia) # https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html
plt.show()

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()

# %%
# Tarea implementar con pandas esta información 
import pandas as pd

df = pd.DataFrame(nivel_estudios)
print(df)
# Out:
#                 0
# 0      Secundaria
# 1      Secundaria
# 2    Bachillerato
# 3           Grado
# 4           Grado
# ..            ...
# 495  Bachillerato
# 496        Master
# 497         Grado
# 498         Grado
# 499  Bachillerato
#
# [500 rows x 1 columns]

# %%
# Frecuencias
frecuencia = df.value_counts()

frecuencia.plot(
    kind = "bar", # tipo de gráfico
    title = "Nivel de Educación", #título del gráfico
    xlabel = "Nivel de Estudios", #etiqueta x
    ylabel = "Personas registradas" #etiqueta y
)
# Out:
# <Axes: title={'center': 'Nivel de Educación'}, xlabel='Nivel de Estudios', ylabel='Personas registradas'>

# %%
# DIAGRAMA DE SECTORES
colores = {'red', 'blue', 'orange', 'green', 'cyan'}
plt.pie(frecuencia, labels=estudios, colors=colores, autopct='%1.2f%%')
plt.title('Diagrama de sectores')
plt.show()
